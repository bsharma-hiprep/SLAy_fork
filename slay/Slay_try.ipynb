# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import slay
import os

# %%
import cupy
import torch

# %%
cupy.cuda.get_local_runtime_version()
# Out:
# 12040

# %%
torch.version.cuda
# Out:
# '12.4'

# %%
if __name__ == "__main__":
    merge_params = {
        "plot_merges": True,
        "max_spikes": 1000,
        "auto_accept_merges": False,
        'good_lbls': ['neural'],
        'xcorr_coeff':0.2
    }

    data_dir = "/home/baibhav/Data/Otto/20240227"

    # Automatically finds all KS 2.5 folders in the data directory
    for root, dirs, files in os.walk(data_dir):
        for dir_name in dirs:
            if "phy_ks" in dir_name:
                ks_dir = os.path.join(root, dir_name)
                print(ks_dir)
                slay.run.main({"KS_folder": ks_dir, **merge_params})
# Out:
# /home/baibhav/Data/Otto/20240227/phy_ks4_o_new
# /home/baibhav/Data/Otto/20240227/phy_ks4_o_new/params.py
# /home/baibhav/Data/Otto/20240227/preprocess/traces_cached_seg0.raw
# Loading files...
# Done, calculating cluster similarity...
# Generating snippets: 100%|██████████| 269/269 [01:12<00:00,  3.70it/s]
# Calculating latent representations: 100%|██████████| 2068/2068 [00:05<00:00, 348.63it/s]
# Average Loss: 7.5818
# Calculating similarity metric:   0%|          | 0/269 [00:00<?, ?it/s]/home/baibhav/A2A/SLAy_fork/SLAy_fork/slay/stages.py:135: RuntimeWarning: invalid value encountered in scalar divide
#   amps[i, p2] / amps[i, p1] * amps[j, p1] / amps[j, p2]
# Calculating similarity metric: 100%|██████████| 269/269 [00:00<00:00, 612.10it/s]
# Found 9.0 candidate cluster pairs
# Calculating cross-correlation metric...
# Calculating refractory period penalty...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 18
#      16 ks_dir = os.path.join(root, dir_name)
#      17 print(ks_dir)
# ---> 18 slay.run.main({"KS_folder": ks_dir, **merge_params})
#
# File ~/A2A/SLAy_fork/SLAy_fork/slay/run.py:16, in main(args)
#      13 params = schema.load(args)
#      14 params["meta_path"] = params["data_filepath"].replace(".bin", ".meta")
# ---> 16 vals, mst, xct, rpt, mt, tt, num_merge, oc = slay.run_merge(params)
#      17 if params["auto_accept_merges"]:
#      18     slay.accept_all_merges(vals, params)
#
# File ~/A2A/SLAy_fork/SLAy_fork/slay/algo.py:157, in run_merge(params)
#     155 # Calculate a refractor period penalty.
#     156 tqdm.write("Calculating refractory period penalty...")
# --> 157 ref_pen, ref_base, ref_obs = slay.calc_ref_p(
#     158     times_multi, n_clust, pass_ms, xcorr_sig, params
#     159 )
#     160 t5 = time.time()
#     161 ref_pen_time = time.strftime("%H:%M:%S", time.gmtime(t5 - t4))
#
# File ~/A2A/SLAy_fork/SLAy_fork/slay/stages.py:260, in calc_ref_p(times_multi, n_clust, pass_ms, xcorr_sig, params)
#     257 c1 = args[i][0]
#     258 c2 = args[i][1]
# --> 260 ref_pen[c1, c2] = res[i][0]
#     261 ref_pen[c2, c1] = res[i][0]
#     263 ref_base[c1, c2] = res[i][1]
#
# IndexError: invalid index to scalar variable.

# %%
dir(slay)
# Out:
# ['CN_AE',
#  'SpikeDataset',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sliding_RP_viol',
#  'accept_all_merges',
#  'algo',
#  'auto_correlogram',
#  'autoencoder',
#  'base_algo',
#  'bin_spike_trains',
#  'bursts',
#  'calc_ae_sim',
#  'calc_mean_wf',
#  'calc_ref_p',
#  'calc_wf_norms',
#  'calc_xcorr_metric',
#  'cluster_metrics',
#  'extract_spikes',
#  'find_best_channels',
#  'find_bursts',
#  'find_times_multi',
#  'generate_train_data',
#  'get_dists',
#  'load_ks_files',
#  'merge_clusters',
#  'parse_cmd_line_args',
#  'parse_kilosort_params',
#  'plot',
#  'plot_merges',
#  'run',
#  'run_merge',
#  'schemas',
#  'spikes_per_cluster',
#  'stages',
#  'train_ae',
#  'utils',
#  'wf_means_similarity',
#  'x_correlogram',
#  'xcorr',
#  'xcorr_sig']
